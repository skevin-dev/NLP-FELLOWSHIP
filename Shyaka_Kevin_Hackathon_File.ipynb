# %% [markdown]
# <a href="https://colab.research.google.com/github/skevin-dev/NLP-FELLOWSHIP/blob/week4/Shyaka_Kevin_Hackathon_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## In this notebook, following tasks will be conducted:
# 1. Write a program which takes array of urls for job-posting websites in Rwanda
#    * https://www.jobinrwanda.com/  (Job Adverts)
#    * https://www.umucyo.gov.rw  ( Tenders)
#
# 2. Web-scrap the content and put them in a pandas data-frame.
#
# 3. Use regular expression and key-words to retrieve IT/Software related job/consultancy opportunities(Tenders).
#
# 4. Use EasyNMT to display the results in 50+ languages using wrapped state of art models.
#
# 5. Hosting of our work example in colab

# %%
# !pip install -U easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: easynmt in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from easynmt) (3.7)
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (from easynmt) (0.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from easynmt) (4.64.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from easynmt) (0.1.97)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from easynmt) (1.21.6)
# Requirement already satisfied: transformers<5,>=4.4 in /usr/local/lib/python3.7/dist-packages (from easynmt) (4.24.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from easynmt) (3.19.6)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from easynmt) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->easynmt) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (0.10.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (4.13.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5,>=4.4->easynmt) (3.0.9)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext->easynmt) (2.10.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext->easynmt) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5,>=4.4->easynmt) (3.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->easynmt) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->easynmt) (1.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (3.0.4)

# %%
# !pip install fastapi pyngrok uvicorn nest-asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastapi in /usr/local/lib/python3.7/dist-packages (0.86.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.7/dist-packages (5.1.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.7/dist-packages (0.19.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (1.5.6)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from fastapi) (1.10.2)
# Requirement already satisfied: starlette==0.20.4 in /usr/local/lib/python3.7/dist-packages (from fastapi) (0.20.4)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.20.4->fastapi) (4.1.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.20.4->fastapi) (3.6.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<5,>=3.4.0->starlette==0.20.4->fastapi) (2.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/dist-packages (from anyio<5,>=3.4.0->starlette==0.20.4->fastapi) (1.3.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (7.1.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (0.14.0)

# %%
# !ngrok authtoken 2HJPtUHZax33oDpfnK1fKxiDPEx_3rHCdzEEgw64LphudF92g
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# import Libraries 

import requests # for requesting a link
from bs4 import BeautifulSoup # to scrap information fron a web 
import pandas as pd # for data wrangling/manipulation 
import re # regular expression 
from easynmt import EasyNMT #for translation 
import json # to read json file
model  = EasyNMT('opus-mt') # for translation
from fastapi import FastAPI, Request #api 
from fastapi.responses import HTMLResponse

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# ## Job in Rwanda

# %%
def DataExtraction(link):
  """ This function helps to extract data about job in rwanda given a link 
  
  Args
  ----
  link:str
      link of the page to be scrapped 

  returns
  -------
  df:dataframe
     a dataset containing all information 
  """
  content =  requests.get(link).content
  soup =  BeautifulSoup(content, "html.parser")


  # find all jobs
  list_of_jobs = soup.find_all('span',class_='field field--name-title field--type-string field--label-hidden')
  jobs_titles = [list_of_jobs[index].text for index in range(len(list_of_jobs))]

  # extract companies 
  content_ = soup.find_all('p',class_='card-text')
  companies = [content_[index].find('a')['href'].split('/')[-1] for index in range(len(content_))]

  # extract experience
  experience = [content_[index].text.split('\n')[-3].strip() for index in range(len(content_))]

  # extract published dates 
  published_dates = [content_[index].text.split('\n')[-6].strip().split(' ')[2] for index in range(len(content_))] 

  # extract deadlines 
  deadlines_list = soup.find_all('time',class_='datetime')

  deadlines = [deadlines_list[d].text for d in range(len(deadlines_list))]
  
  # job description
  descriptions = soup.find_all('div',class_='card-body p-2')
  descriptions_links = ['https://www.jobinrwanda.com'+descriptions[index].find('a')['href']for index in range(len(descriptions))]

  # type of the job
  types = [content_[index].find('span').getText() for index in range(len(content_))]
  
  # # creating empty lists 
  # location= []
  Sector = []
  position = []
  contract = []
  application_link = []
  description = []
  # iterate through list of description links 
  for link_ in descriptions_links:
    content_ =  requests.get(link_).content
    soup_ =  BeautifulSoup(content_, "html.parser")
    b= soup_.find('ul',class_="list-group list-group-flush").text
    c =  b.split('\n')
    # remove unnecessary white spaces 
    res = [ele for ele in c if ele.strip()]

    text ="\n".join([" ".join(line.split()) for line in res])

    # retrieving information
    
    # sector
    sector = re.findall('Sector:\n(.+)\n',text)
    Sector.append(" ".join(sector))

    #contract type
    contract.append("".join(re.findall('Contract\stype\n:\s+(.+)\n',text)))

    #positions
    position.append("".join(re.findall('positions:\s(\d+)',text))) 

    #application link
    try:

      f = soup_.find('li',class_='list-group-item px-0 pb-0 job-apply-btn d-grid').find('a')['href']
      application_link.append('https://www.jobinrwanda.com'+f)

    except:
      application_link.append('No Link Available')

    #description
    des = soup_.find('div',class_='clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item').text
    description.append(" ".join(des.split('\n')))
 
 
  # create an empty dataframe 
  df = pd.DataFrame()

  # create columns and assigning values 
  df['Job Titles'] = jobs_titles
  df['Çompanies'] = companies 
  df['Experience'] = experience
  df['Published Date']  =published_dates
  df['Deadline'] = deadlines
  # df['Location'] = location
  df['Number of Position'] = position
  df['Contract Type'] = contract
  # df['Education Level']=education
  df['Description content'] =description
  df['Sectors'] = Sector
  df['Application Link'] = application_link
  df['Type'] = types
 
  return df

# %%
def retrieving_link(baselink):
  """this function helps to retrieve all the links including jobs,tenders,internship and consultancy

  Args
  ----
  Baselink:str
     The baselink of the page of job in rwanda websites 

  Returns
  -------
  jobs_link: the link of all jobs
  consultancy_link : the link of all consultancies
  tender_link: the link of all tenders
  internship_link: the link of all internships
  """
  content =  requests.get(baselink).content
  soup =  BeautifulSoup(content, "html.parser")
  list_of_links = []
  for name in ['all','consultancy','tender','internships']:
    name = baselink + soup.find('a',class_='nav-link px-1 text-primary nav-link--jobs-{}'.format(name))['href']
    list_of_links.append(name)

  return list_of_links

# %% [markdown]
# ### Loop through different links and extract data

# %%
baselink = 'https://www.jobinrwanda.com'
data =  []
for i in range(4):
  df = DataExtraction(retrieving_link(baselink)[i])
  data.append(df)
df = pd.concat(data,ignore_index = True)
df
# Out:
#                                             Job Titles  \
# 0                                   Operations Manager
# 1                              Account Manager- Credit
# 2                                        Legal Manager
# 3         District Coordinator/Junior District Manager
# 4                               Radio Sales Executives
# ..                                                 ...
# 162       Supply and Installation of Medical Equipment
# 163  Supply and Delivery of Laboratory Commodities ...
# 164  Supply of Laboratory Reagents, Equipments and ...
# 165        Labor Mobility and Human Development Intern
# 166                          Communications Internship
#
#                                       Çompanies  \
# 0                                    gardaworld
# 1                                        yellow
# 2                                    copedu-plc
# 3                            earthenable-rwanda
# 4                               royal-radio-ltd
# ..                                          ...
# 162                   rwanda-medical-supply-ltd
# 163                   rwanda-medical-supply-ltd
# 164                   rwanda-medical-supply-ltd
# 165  international-organization-migration-iom-0
# 166                       land-olakes-venture37
#
#                                    Experience Published Date    Deadline  \
# 0             Senior (5+ years of experience)     03-11-2022  14-11-2022
# 1                               Not specified     27-10-2022  27-11-2022
# 2     Mid career (3 to 5 years of experience)     12-11-2022  18-11-2022
# 3                               Not specified     11-11-2022  30-11-2022
# 4                               Not specified     10-11-2022  15-11-2022
# ..                                        ...            ...         ...
# 162                             Not specified     19-10-2022  17-11-2022
# 163                             Not specified     19-10-2022  22-11-2022
# 164                             Not specified     19-10-2022  15-11-2022
# 165  Entry level (1 to 3 years of experience)     09-11-2022  22-11-2022
# 166                             Not specified     09-11-2022  23-11-2022
#
#     Number of Position Contract Type  \
# 0                    1     Full-time
# 1                    1     Full-time
# 2                    1     Full-time
# 3                    1     Full-time
# 4                    3     Full-time
# ..                 ...           ...
# 162                  1        Tender
# 163                  1        Tender
# 164                  1        Tender
# 165                  1    Internship
# 166                  1    Internship
#
#                                    Description content  \
# 0    Job Description – Operations Manager  Position...
# 1    Position: Account Manager- Credit Locations: M...
# 2    NOTICE OF RECRUITMENT COPEDU PLC, is a trading...
# 3    JOB DESCRIPTION: DISTRICT COORDINATOR/JUNIOR D...
# 4    JOB OPPORTUNITY 94.3 ROYAL FM is opening up a ...
# ..                                                 ...
# 162  Invitation for Bids TITLE:  SUPPLY AND INSTALL...
# 163  Invitation for Bids TITLE:  SUPPLY AND DELIVER...
# 164  Invitation for Bids TITLE:  SUPPLY OF LABORATO...
# 165  CALL FOR APPLICATIONS FOR INTERNSHIP  Position...
# 166  POSITION DESCRIPTION Communications Internship...
#
#                                                Sectors  \
# 0          Administration, Business, Management, Other
# 1                                                Other
# 2                   Finance and investment, Law, Other
# 3                                    Management, Other
# 4                           Marketing and sales, Other
# ..                                                 ...
# 162                                              Other
# 163                                              Other
# 164                                              Other
# 165  Administration, Other, Project management, Soc...
# 166                  Communications, Journalism, Other
#
#                                       Application Link        Type
# 0    https://www.jobinrwanda.com/form/default-job-a...         Job
# 1    https://www.jobinrwanda.comhttps://www.yellow....         Job
# 2    https://www.jobinrwanda.com/form/default-job-a...         Job
# 3    https://www.jobinrwanda.comhttps://docs.google...         Job
# 4    https://www.jobinrwanda.com/form/default-job-a...         Job
# ..                                                 ...         ...
# 162                                  No Link Available      Tender
# 163                                  No Link Available      Tender
# 164                                  No Link Available      Tender
# 165  https://www.jobinrwanda.com/form/default-job-a...  Internship
# 166  https://www.jobinrwanda.com/form/default-job-a...  Internship
#
# [167 rows x 11 columns]

# %% [markdown]
# ### Extract all data from features

# %%
baselink = 'https://www.jobinrwanda.com'

content =  requests.get(baselink).content
soup =  BeautifulSoup(content, "html.parser")
features_link = baselink + soup.find('a',class_='nav-link px-1 active bg-primary border-primary text-white nav-link--jobs-featured')['href']

# %%
df1_all_features = DataExtraction(features_link)

# %%
df1_all_features
# Out:
#                                             Job Titles  \
# 0         Hiring a Firm for BRD Maintenance Assessment
# 1                    Construction du Guichet de Byumba
# 2                  Consultant- Monitoring & Evaluation
# 3                                   Operations Manager
# 4    Terms of Reference for Production Of the Secon...
# ..                                                 ...
# 165                                   Rwanda Tree Lead
# 166                  Rwanda Potato Seed Venture ﻿﻿Lead
# 167                       IT Operations Senior Manager
# 168                 Rwanda Seed Innovation Centre Lead
# 169                            Senior Business Analyst
#
#                                          Çompanies  \
# 0                      development-bank-rwanda-brd
  df_it: dataframe
     dataset of IT jobs only
  """

  #all IT keywords
  IT_keywords = ['information technology','technology','IT','cyber security','tech','computer science','programming','business','coding','innovation',
               'software','python','information','computer','information security','technology news','java','networking','hacking','programmer','linux',
               'technology rocks','coder','technology these days','cloud computing','education','engineering','it services','new technology','data analysis','data science','AI','machine learning']

  # creating a regex pattern for keyowrds
  keyword_pattern = re.compile( "|".join(IT_keywords))

  numbers = []

  numbers_sector = []

  # loop through columns to see if there are keywords 
  for index in range(len(df)):
    # if a list because, description can be a text also 
    if type(df[col1][0]) is list:
      description = " ".join(df[col1][index])
      numbers.append(len(set(re.findall(keyword_pattern,description))))
    else: 
      numbers.append(len(set(re.findall(keyword_pattern,df[col1][index]))))

    numbers_sector.append(len(set(re.findall(keyword_pattern,df[col2][index]))))

  df['Number of IT keywords appeared in {}'.format(col1)] = numbers 
  df['number of keywords in this columns {}'.format(col2)] = numbers_sector

  # filtering IT jobs ( jobs that have at least 5 keywords in entire description and at least 1 in sector)
  df_it = df.loc[(df['Number of IT keywords appeared in {}'.format(col1)] >= 5) & (df['number of keywords in this columns {}'.format(col2)] >=1)]


  # reset index since we did filtering 
  df_it.reset_index(inplace=True)
  
  # delete the existing index 
  del df_it['index']

  return df_it

# %%
df_it = is_it(df1_all_features,"Description content","Sectors")

# %%
df_it
# Out:
#                                 Job Titles              Çompanies  \
# 0                          Product Manager   ampersand-rwanda-ltd
# 1  Global Client Data Analytics Consultant          one-acre-fund
# 2                      IT and MIS Director  chancen-international
# 3             IT Operations Senior Manager          one-acre-fund
# 4                  Senior Business Analyst          one-acre-fund
#
#                         Experience Published Date    Deadline  \
# 0  Senior (5+ years of experience)     10-11-2022  10-01-2023
# 1  Senior (5+ years of experience)     08-11-2022  20-12-2022
# 2  Senior (5+ years of experience)     31-10-2022  18-11-2022
# 3                    Not specified     07-09-2022  06-12-2022
# 4                                      22-08-2022  17-11-2022
#
#   Number of Position Contract Type  \
# 0                  1     Full-time
# 1                  1      Contract
# 2                  1     Full-time
# 3                  1     Full-time
# 4                  1     Full-time
#
#                                  Description content  \
# 0  Do you want to do work that matters? Do you wa...
# 1  About One Acre Fund Founded in 2006, One Acre ...
# 2  CHANCEN International is a non-profit organiza...
# 3  About One Acre Fund Founded in 2006, One Acre ...
# 4  ABOUT ONE ACRE FUND Founded in 2006, One Acre ...
#
#                                              Sectors  \
# 0    Computer and IT, Management, Project management
# 1  Agriculture, Business, Demography and data ana...
# 2         Computer and IT, Other, Project management
# 3  Agriculture, Business, Computer and IT, Manage...
# 4  Agriculture, Business, Demography and data ana...
#
#                                     Application Link         Type  \
# 0  https://www.jobinrwanda.comhttps://ampersandel...          Job
# 1  https://www.jobinrwanda.comhttps://grnh.se/ae4...  Consultancy
# 2  https://www.jobinrwanda.com/form/default-job-a...          Job
# 3  https://www.jobinrwanda.comhttps://grnh.se/304...          Job
# 4  https://www.jobinrwanda.comhttps://grnh.se/c02...          Job
#
#    Number of IT keywords appeared in Description content  \
# 0                                                  5
# 1                                                  6
# 2                                                 10
# 3                                                  6
# 4                                                  5
#
#    number of keywords in this columns Sectors
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1

# %% [markdown]
# ## Umucyo

# %%
def DataExtractionUmucyo(filepath: str):
  """this function helps to extract data from umucyo

  Args
  ----
  filepath:str
     filepath of txt file containing html file of all page after navigating view frame source 
       
  returns
  -------
  df: dataframe
      dataset of the data 
  """
  # given the path to text file of format of the page, I extract 50 records 
  page_content = ""
  with open(filepath,'r') as file:
    for line in file.readlines():
      page_content +=line
  soup =  BeautifulSoup(page_content, "html.parser")

  table = soup.find('table',class_='article_table mb10')

  # extract headers'name of the table 
  headers = [re.sub('[^A-Za-z0–9]',"",title.text) for title in table.find_all('th')[1:]]

  # extract data 
  data = []
  for row in table.find_all('tr')[1:]:
    d =  row.find_all('td')[1:]
    row_data = [ele.text.strip() for ele in d]
    data.append(row_data)

  # create a dataframe 
  df = pd.DataFrame(data,columns =headers)

  return df

# %%
df_umucyo = DataExtractionUmucyo('/content/umucyo_frame_work.txt')

# %%
df_umucyo
# Out:
#                                            TenderName  \
# 0   Hiring consultant Urban Mobility (Public trans...
# 1   Hiring consultant Transport economist to suppo...
# 2               science kits and laboratory equipment
# 3   Hiring an international Expert in Data Process...
# 4           TENDER FOR OFFICE SUPPLIES AND STATIONARY
# 5        supply of labo kits reagents and consumables
# 6   Provision of services of raising awareness on ...
# 7   Rehabilitation of administration bloc, constru...
# 8   Hiring a consultant firm for Study review and ...
# 9   Supply of calibration certified reference mate...
# 10  Hiring consultant Traffic signal engineer to s...
# 11  Supply of laboratory gases on a framework cont...
# 12      Supply of Stationary and printing consumables
# 13  Consultancy services in support of upgrading t...
# 14                     RP Head Quarters Refurbishment
# 15  Supervision of RP Head Quarters Refurbishment ...
# 16  Provision of Maintenance and repair service of...
# 17   Supply and fixation of curtains for IPRC Musanze
# 18  Maintenance of IT equipment and supply of rela...
# 19  Supply of construction materials for SP-Epw; S...
# 20                                     HOTEL SERVICES
# 21                        Supply of printed materials
# 22  Supply of materials testing reference material...
# 23  Technical assistance to assess social impact o...
# 24  Provision of restaurant services  at UR Gikond...
# 25  VEHICLES AND MOTORCYCLES REPARATION AND SPARE-...
# 26                     Provision of cleaning Services
# 27         Supply and installation of bill sign board
# 28     Tender for purchase Bale  machine and tractors
# 29  Annual framework tender  for supply of food an...
# 30  Network rehabilitation and Disaster recovery (...
# 31  Feasibility study of cheap seal road type DBST...
# 32  Supply and Delivery of Stationeries and printi...
# 33                   OFFICE SUPPLIES AND STATIONARIES
# 34  Hiring Tents, Chairs, Tables and their decoration
# 35  Feasibility and technical study for constructi...
# 36  Hiring tents,  decoration and other gods  in t...
# 37        Cleaning Services to the Ministry of Sports
# 38  Production and broadcasting services for Gisag...
# 39  Supply of nametag and table for councilor's, G...
# 40                      Service of asset codification
# 41  Acquisition of supplements for foodstuffs, bri...
# 42  Supervision of Construction works of Chipseal ...
# 43  supply of Fruits and vegetable drying machines...
# 44  Re-advertised Supply of planting and maintenan...
# 45  Fourniture de carburant essence et mazout. Rel...
# 46  Construction of chipseal roads (1.55km) in Ndo...
# 47  Acquisition of construction materials for Nyam...
# 48  Supply of Fuel to IPRC Kigali under framework ...
# 43     12/12/2022 09:00  12/12/2022 09:30  one stage
# 44     12/12/2022 09:00  12/12/2022 09:30  one stage
# 45     12/12/2022 09:00  12/12/2022 09:30  one stage
# 46     12/12/2022 09:00  12/12/2022 09:30  one stage
# 47     12/12/2022 09:00  12/12/2022 09:30  one stage
# 48     12/12/2022 09:00  12/12/2022 09:30  one stage
# 49     12/12/2022 09:00  12/12/2022 09:30  one stage

# %% [markdown]
# ## Data Translation and API

# %%
# load json file containing languages and their codes 

with open('/content/langs.json','r+') as file:
  content =  file.read()
languages_dict = json.loads(content)

# %%
app = FastAPI(title='MY FASTAPI') #Starting the FastAPI instance


@app.get('/')#ROUTE
def index():
    return "This is hackathon, to extract data in english add /data/jobinrwanda to the link in your browser. For the language of your add to the link ?language= add your language"


@app.get('/data/jobinrwanda')
def get_data(language:str =None):
  """This function help to get data on the api by entering the language of your choice 

  Args
  ----
  language:str
       the language to be translated into
  Returns
  -------
  json file of the data 
  """
  # copy the dataframe for easy translation(so that translation have to be always from english)
  df_copy = df_it.copy()
  
  # use try and except so that if the user enter the wrong language, the program will not crush 
  try:
    if language:
      # translate the job title, we use .title() to allow any case the use can type the language 

      #Translate job titles 
      df_copy['Job Titles'] = model.translate(df_copy['Job Titles'],target_lang =languages_dict[language.title()])
 
      # translate description. take few first characters to easy translation 
      df_copy['Description content'] = model.translate(df_copy['Description content'][0:500],target_lang =languages_dict[language.title()])

      return df_copy.to_dict('r')
    
    # if the user doesn't include any language it will print the data in english 
    else:
      df_copy['Job Titles'] = model.translate(df_copy['Job Titles'],target_lang ="en")
      return df_copy.to_dict('r')
  
  except:
    message = "The entered language is not available, please use one of this languages: {}".format([keys for keys,values in languages_dict.items()])
    return message 

@app.get('/data/umucyo')
def get_data(language:str =None):
  """This function help to get data on the api by entering the language of your choice 

  Args
  ----
  language:str
       the language to be translated into
  Returns
  -------
  json file of the data 
  """
  # copy the dataframe for easy translation(so that translation have to be always from english)
  df_copy_umucyo = df_umucyo.copy()
  
  # use try and except so that if the user enter the wrong language, the program will not crush 
  try:
    if language:
      # translate the job title, we use .title() to allow any case the use can type the language 

      #Translate tender name 
      df_copy_umucyo['TenderName'] = model.translate(df_copy_umucyo['TenderName'],target_lang =languages_dict[language.title()])
 


      return df_copy_umucyo.to_dict('r')
    
    # if the user doesn't include any language it will print the data in english 
    else:
      df_copy_umucyo['TenderName'] = model.translate(df_copy_umucyo['TenderName'],target_lang ="en")
      return df_copy_umucyo.to_dict('r')
  
  except:
    message = "The entered language is not available, please use one of this languages: {}".format([keys for keys,values in languages_dict.items()])
    return message

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

ngrok_tunnel = ngrok.connect(8000)
print("REST API started")
print("Your public API URL:", ngrok_tunnel.public_url)
print("You can for example open the following URL in your browser: {}?target_lang=en&text=Hallo%20Welt".format(ngrok_tunnel.public_url))

nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [76]

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### all CSV files: https://drive.google.com/drive/folders/1N853LwSHtm6TaPzBm9JQgyNqKX7ZBcdY?usp=sharing

# %% [markdown]
# ## Report

# %% [markdown]
# ###report link: https://drive.google.com/drive/folders/1gPMPGH1VaubvP2lAs2ettC2dQfC0eInk?usp=sharing
